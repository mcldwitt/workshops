# %% [markdown]
# <a href="https://colab.research.google.com/github/mcldwitt/workshops/blob/main/Workshop_generative_AI_deel_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='darkorange'> De pinguïn dataset
# Vraag aan ChatGPT of google gemini hoe je de pinguïn dataset kunt importeren uit de seaborn library.
# Deze dataset is een zeer gekende dataset en bestaat uit 3 soorten pinguïns: Adelie, Gentoo en Chinstrap pinguïns.
#
# ![penguins.jpeg](data:image/jpeg;base64,...)
#
# Het doel is om te proberen met een AI algoritme te voorspellen om welke soort pinguïn ieder rijtje in de dataset is.
